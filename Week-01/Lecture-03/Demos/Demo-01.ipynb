# %% [markdown]
# # بسم الله الرحمن الرحيم

# %%
class Human:
    def __init__(self, name):
        self.name = name

# %%
ahmed = Human()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-0e30be77093c> in <module>
# ----> 1 ahmed = Human()
#
# TypeError: __init__() missing 1 required positional argument: 'name'

# %%
ahmed = Human('ahmed')

# %%
type(ahmed)
# Out:
# __main__.Human

# %%
ahmed.name
# Out:
# 'ahmed'

# %%
mahmoud = Human('mahmoud')

# %%
mahmoud.name
# Out:
# 'mahmoud'

# %%
class Human:
    def __init__(self, name):
        self.name = name
        print(f'New Object with name {self.name} has been created')

# %%
ahmed = Human('ahmed')
# Out:
# New Object with name ahmed has been created

# %%
mahmoud.name = 'Mohammed'

# %%
mahmoud.name
# Out:
# 'Mohammed'

# %%
ahmed.name
# Out:
# 'ahmed'

# %% [markdown]
# ## Class Variable

# %%
class Human:
    no_faults = 0
    def __init__(self, name):
        self.name = name
        print(f'New Object with name {self.name} has been created')

# %%
a = Human('ahmed')
b = Human('Bahy')
c = Human('Samer')
# Out:
# New Object with name ahmed has been created
# New Object with name Bahy has been created
# New Object with name Samer has been created

# %%
# Instance Variable
a.name
# Out:
# 'ahmed'

# %%
b.name
# Out:
# 'Bahy'

# %%
c.name = 'Kareem'

# %%
c.name
# Out:
# 'Kareem'

# %%
a.name
# Out:
# 'ahmed'

# %%
# Class Variable
Human.no_faults
# Out:
# 0

# %%
Human.no_faults += 1

# %%
# Using class to change the value will reflect with all instances
Human.no_faults
# Out:
# 1

# %%
a.no_faults
# Out:
# 1

# %%
b.no_faults
# Out:
# 1

# %%
c.no_faults
# Out:
# 1

# %%
# However, using Object specifically will result in: Shadowing
c.no_faults += 1

# %%
c.no_faults
# Out:
# 2

# %%
a.no_faults
# Out:
# 1

# %%
b.no_faults
# Out:
# 1

# %%
# Shadowing Check
c.no_faults += 1

# %%
c.no_faults
# Out:
# 3

# %%
a.no_faults
# Out:
# 1

# %%
b.no_faults
# Out:
# 1

# %%
a.no_faults += 1

# %%
c.no_faults
# Out:
# 3

# %%
a.no_faults
# Out:
# 2

# %%
c.no_faults
# Out:
# 3

# %%
b.no_faults
# Out:
# 1

# %%
Human.no_faults
# Out:
# 1

# %%
Human.no_faults += 1

# %%
b.no_faults
# Out:
# 2

# %% [markdown]
# ## Instance Method

# %%
class Human:
    no_faults = 0
    def __init__(self, name):
        self.name = name
    def speak(self):
        print(f'My name is: {self.name}')

# %%
a = Human('ahmed')
b = Human('Bahy')
c = Human('Samer')

# %%
a.speak
# Out:
# <bound method Human.speak of <__main__.Human object at 0x7f9c3be807b8>>

# %%
id(a)
# Out:
# 140308996687800

# %%
hex(id(a))
# Out:
# '0x7f9c3be807b8'

# %%
bin(id(a))
# Out:
# '0b11111111001110000111011111010000000011110111000'

# %%
oct(id(a))
# Out:
# '0o3771607372003670'

# %%
a.speak()
# Out:
# My name is: ahmed

# %%
b.speak()
# Out:
# My name is: Bahy

# %%
c.speak()
# Out:
# My name is: Samer

# %% [markdown]
# ## Class Methods

# %%
class Human:
    no_faults = 0
    def __init__(self, name):
        self.name = name
        print(f'New Object with name {self.name} has been created')
        
    @classmethod
    def make_fault(cls):
        cls.no_faults += 1
        print(cls.no_faults)

# %%
b = Human('Bahy')
c = Human('Careem')
# Out:
# New Object with name Bahy has been created
# New Object with name Careem has been created

# %%
Human.no_faults
# Out:
# 0

# %%
b.no_faults
# Out:
# 0

# %%
c.no_faults
# Out:
# 0

# %%
Human.make_fault()
# Out:
# 1

# %%
c.no_faults
# Out:
# 1

# %%
# a.make_fault()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-86c5eee9f6b1> in <module>
# ----> 1 a.make_fault()
#
# AttributeError: 'Human' object has no attribute 'make_fault'

# %%
b.make_fault()
# Out:
# 2

# %%
c.no_faults
# Out:
# 2

# %%
Human.no_faults
# Out:
# 2

# %% [markdown]
# ## Static Method

# %%
class Student:
    def __init__(self, name):
        self.name = name
    
    @staticmethod
    def avg(*args):
        result = 0
        for arg in args:
            result += arg
        return result / len(args)

# %%
Student.avg(1,2,3,4,5)
# Out:
# 3.0

# %%
a = Student('Ahmed')

# %%
b = Student('Bahy')

# %%
a.avg(1,2,3,4,5)
# Out:
# 3.0

# %% [markdown]
# ## Inheritance

# %%
class Human:
    def __init__(self):
        print('New Human was created')
    def say_hello(self):
        print('Hello!')

# %%
class Person(Human):
    pass

# %%
a = Person()
# Out:
# New Human was created

# %%
a.say_hello()
# Out:
# Hello!

# %%
class Human:
    def __init__(self, name):
        self.name = name
        self.walk_distance = 0
        print(f'New Human Object was Created {self.name}')
        
    def walk(self):
        self.walk_distance += 1
        print(f'I have walked {self.walk_distance} meters')

# %%
class Person(Human):
    pass

# %%
a = Person()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-132939cb5928> in <module>
# ----> 1 a = Person()
#
# TypeError: __init__() missing 1 required positional argument: 'name'

# %%
a = Person('Ahmed')
# Out:
# New Human Object was Created Ahmed

# %%
a.name
# Out:
# 'Ahmed'

# %%
a.walk_distance
# Out:
# 0

# %%
a.walk()
# Out:
# I have walked 1 meters

# %% [markdown]
# ## Calling Parent Constructor

# %%
class Person:
    def __init__(self, name):
        self.name = name
        print('New Person has been created')
        
class Employee(Person):
    def __init__(self, position):
        self.position = position
        print('New Employee has been created')

# %%
a = Person('Ahmed')
# Out:
# New Person has been created

# %%
b = Employee('Information Systems')
# Out:
# New Employee has been created

# %%
type(b)
# Out:
# __main__.Employee

# %%
class Person:
    def __init__(self, name):
        self.name = name
        print('New Person has been created')
        
class Employee(Person):
    def __init__(self, name, position):
        super(Employee, self).__init__(name)
        self.position = position
        print('New Employee has been created')

# %%
b = Employee('Bahy', 'Information Systems')
# Out:
# New Person has been created
# New Employee has been created

# %%
class Person:
    def __init__(self, name):
        self.name = name
        print('New Person has been created')
        
class Employee(Person):
    def __init__(self, name, position):
        Person.__init__(self, name)
        self.position = position
        print('New Employee has been created')

# %%
b = Employee('Bahy', 'Information Systems')
# Out:
# New Person has been created
# New Employee has been created

# %% [markdown]
# ## Multiple Inheritance

# %%
class Human:
    def __init__(self, name):
        self.name = name
        print('New Human has been created')
    def eats(self):
        print('I was hugry!')
    def sleeps(self):
        print('I wanna sleep!')
        
class Employee():
    def __init__(self, name, position):
        self.name = name
        self.position = position
        print('New Employee has been created')
        
    def work(self):
        print('I am working right now!')
        
class Manager(Human, Employee):
    pass

# %%
m = Manager()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-4c562f2ffaf7> in <module>
# ----> 1 m = Manager()
#
# TypeError: __init__() missing 1 required positional argument: 'name'

# %%
m = Manager('Ahmed')
# Out:
# New Human has been created

# %%
m.work()
# Out:
# I am working right now!

# %%
class Human:
    def __init__(self, name):
        self.name = name
        print('New Human has been created')
    def eats(self):
        print('I was hugry!')
    def sleeps(self):
        print('I wanna sleep!')
        
class Employee():
    def __init__(self, name, position):
        self.name = name
        self.position = position
        print('New Employee has been created')
        
    def work(self):
        print('I am working right now!')
        
class Manager(Human, Employee):
    def __init__(self, name, position):
        Human.__init__(self, name)
        Employee.__init__(self, name, position)

# %%
m = Manager('Bahy', 'Information Systems')
# Out:
# New Human has been created
# New Employee has been created

# %%
class Human:
    def __init__(self, name):
        self.name = name
        print('New Human has been created')
    def eats(self):
        print('As a Human, I was hugry!')
    def sleeps(self):
        print('I wanna sleep!')
        
class Employee():
    def __init__(self, name, position):
        self.name = name
        self.position = position
        print('New Employee has been created')
        
    def work(self):
        print('I am working right now!')
        
    def eats(self):
        print('As an Employee, I was hugry!')
        
class Manager(Human, Employee):
    def __init__(self, name, position):
        Human.__init__(self, name)
        Employee.__init__(self, name, position)

# %%
m = Manager('Bahy', 'Information Systems')
# Out:
# New Human has been created
# New Employee has been created

# %%
m.eats()
# Out:
# As a Human, I was hugry!

# %%
class Human:
    def __init__(self, name):
        self.name = name
        print('New Human has been created')
    def eats(self):
        print('As a Human, I was hugry!')
    def sleeps(self):
        print('I wanna sleep!')
        
class Employee():
    def __init__(self, name, position):
        self.name = name
        self.position = position
        print('New Employee has been created')
        
    def work(self):
        print('I am working right now!')
        
    def eats(self):
        print('As an Employee, I was hugry!')
        
class Manager(Human, Employee):
    def __init__(self, name, position):
        Human.__init__(self, name)
        Employee.__init__(self, name, position)
        
    def eats(self):
        print('An a Manager, I was hungry!')

# %%
m = Manager('Bahy', 'Information Systems')
# Out:
# New Human has been created
# New Employee has been created

# %%
m.eats()
# Out:
# An a Manager, I was hungry!

# %% [markdown]
# ## Method Overloading

# %%
# int add (int x, int y){
#     return x + y;
# }

# %%
# float add (float x, float y){
#     return x + y;
# }

# %%
# def add (x, y, *args):
#     return x + y

# %% [markdown]
# ## Encapsulation

# %%
class Student:
    def __init__(self, name):
        self.name = name
        self.age = -1

# %%
b = Student('Bahy')

# %%
b.age = -200 # Not Accepted

# %%
class Student:
    def __init__(self, name):
        self.name = name
        # Double Underscore -> Naming Convention
        self.__age = -1

# %%
b = Student('Bahy')

# %%
b.age = -200

# %%
b.age
# Out:
# -200

# %%
class Student:
    def __init__(self, name):
        self.name = name
        self.__age = -1
        
    def get_age(self):
        return self.__age
    
    def set_age(self, age):
        if age < 4 or age > 25:
            return('Enter Valid Value')
        else:
            self.__age = age

# %%
b = Student('Bahy')

# %%
b.set_age(0)
# Out:
# 'Enter Valid Value'

# %%
b.set_age(200)
# Out:
# 'Enter Valid Value'

# %%
b.__age = -200

# %%
b.get_age()
# Out:
# -1

# %%
class Student:
    def __init__(self, name):
        self.name = name
        self.age = -1
        
    @property
    def age(self):
        return self.__age
    
    @age.setter
    def age(self, age):
        if age < 4 or age > 25:
            return('Enter Valid Value')
        else:
            self.__age = age

# %%
b = Student('Bahy')

# %%
b.age = 20

# %%
b.age = -200

# %%
b.age
# Out:
# 20

# %%
print(b)
# Out:
# <__main__.Student object at 0x7f9c3bdb1978>

# %%
class Student:
    def __init__(self, name):
        self.name = name
        self.age = -1
        
    @property
    def age(self):
        return self.__age
    
    @age.setter
    def age(self, age):
        if age < 4 or age > 25:
            return('Enter Valid Value')
        else:
            self.__age = age
            
    def __str__(self):
        return(f'I am Student and my name is: {self.name}')
    
    def __len__(self):
        return 20

# %%
b = Student('Bahy')

# %%
print(b)
# Out:
# I am Student and my name is: Bahy

# %%
len([1,2,3,4])
# Out:
# 4

# %%
len(b)
# Out:
# 20

# %% [markdown]
# ## lambda function

# %%
fn = lambda x: x + 4

# %%
type(fn)
# Out:
# function

# %%
fn(5)
# Out:
# 9

# %%
fn([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-152-d5adb84229ae> in <module>
# ----> 1 fn([1,2,3])
#
# <ipython-input-149-a69521dd5a73> in <lambda>(x)
# ----> 1 fn = lambda x: x + 4
#
# TypeError: can only concatenate list (not "int") to list

# %%
for i in range(3):
    print(fn(i))
# Out:
# 4
# 5
# 6

# %%
def sum_fn(n):
    return lambda x: x + n

# %%
sum_fn(2)
# Out:
# <function __main__.sum_fn.<locals>.<lambda>(x)>

# %%
sum_fn(2)(5)
# Out:
# 7

# %%
x = range(2)

# %%
it = iter(x)

# %%
type(it)
# Out:
# range_iterator

# %%
next(it)
# Out:
# 0

# %%
next(it)
# Out:
# 1

# %%
next(it)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-173-bc1ab118995a> in <module>
# ----> 1 next(it)
#
# StopIteration:

# %%
map(lambda x: x+4, [1,2,3])

# %%
x = map(lambda x: x+4, [1,2,3])

# %%
x

# %%
for i in x:
    print(i)
# Out:
# 5
# 6
# 7

# %%
y = filter(lambda x: x % 5 == 0, range(20))

# %%
for i in y:
    print(i)
# Out:
# 0
# 5
# 10
# 15
