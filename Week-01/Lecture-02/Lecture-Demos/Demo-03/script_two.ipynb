# %% [markdown]
# # بسم الله الرحمن الرحيم

# %%
f = open('out.txt', 'w')

f.write('This is Line-01\n')
f.write('This is Line-02\n')

f.close()

# %%
f = open('out.txt', 'r')
f.read()
f.close()

# %%
f = open('out.txt', 'r')
f.read(4)

# %%
f.read(4)

# %%
f.readline()

# %%
f.close()

# %%
f = open('out.txt', 'r')
f.read(4)

# %%
f.seek(0)

# %%
f.readline()

# %%
f.readline()

# %%
f.readline()

# %%
f.close()

# %%
f = open('out.txt', 'r')
l = f.readlines()

# %%
l

# %%
f.close()

# %%
f = open('out.txt', 'r')
for l in f.readlines():
    print(l)

# %%
f
# Out:
# <_io.TextIOWrapper name='out.txt' mode='w' encoding='UTF-8'>

# %%
f.write('This is another line \n')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-f6c9ff02ad89> in <module>
# ----> 1 f.write('This is another line \n')
#
# ValueError: I/O operation on closed file.

# %%
# Closes connection to file automatically
with open('out.txt', 'a') as file:
    file.write('Written by open statement')

# %%
file.write('This is another line \n')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5304066fb90f> in <module>
# ----> 1 file.write('This is another line \n')
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# # Standard Library

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/helghareeb/DSA20/Week-01/Lecture-02/Lecture-Demos/Demo-03'

# %%
# Creates New Directory
os.system('mkdir tmp')
# Out:
# 0

# %%
# Deletes the Directory
os.system('rmdir tmp')
# Out:
# 0

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/home/helghareeb/DSA20/Week-01/Lecture-02/Lecture-Demos'

# %%
os.getlogin()
# Out:
# 'helghareeb'

# %%
import math

# %%
math.pow(2, 3)
# Out:
# 8.0

# %%
from math import pow

# %%
pow(3,4)
# Out:
# 81.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import re

# %%
# https://docs.python.org/3/howto/regex.html
# https://www.w3schools.com/python/python_regex.asp

# %%
txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt) 
x
# Out:
# <re.Match object; span=(0, 17), match='The rain in Spain'>

# %% [markdown]
# # List Comprehension

# %%
my_list = [1,2,3]

# %%
new_list = []
for item in my_list:
    new_list.append(item * 2)
new_list
# Out:
# [2, 4, 6]

# %%
[item * 2 for item in my_list]
# Out:
# [2, 4, 6]

# %%
# my_list = [1,2,3,4,5,6,7,8,9]
# Pythonic way
my_list = range(1,10)

# %%
new_list = []
for item in my_list:
    if item % 2 == 0:
        new_list.append(item * 2)
new_list
# Out:
# [4, 8, 12, 16]

# %%
[item * 2 for item in my_list if item % 2 == 0]
# Out:
# [4, 8, 12, 16]

# %%
for i, t in enumerate(my_list):
    print(f'Index: {i} has value {t}')
# Out:
# Index: 0 has value 1
# Index: 1 has value 2
# Index: 2 has value 3
# Index: 3 has value 4
# Index: 4 has value 5
# Index: 5 has value 6
# Index: 6 has value 7
# Index: 7 has value 8
# Index: 8 has value 9

# %%
my_list
# Out:
# range(1, 10)

# %%
my_dict = dict(my_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-6c3402f89cb4> in <module>
# ----> 1 my_dict = dict(my_list)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
keys = [0,1,2]
values = ['zero', 'one', 'two']

# %%
my_dict = dict(zip(keys, values))

# %%
my_dict
# Out:
# {0: 'zero', 1: 'one', 2: 'two'}

# %%
for k,v in enumerate(my_dict):
    print(f'Key {k} has Value {v}')
# Out:
# Key 0 has Value 0
# Key 1 has Value 1
# Key 2 has Value 2
